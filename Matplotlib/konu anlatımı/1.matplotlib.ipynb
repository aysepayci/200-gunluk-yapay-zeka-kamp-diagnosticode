# %% [markdown]
#     Matplotlib

# %% [markdown]
# ![alt text](image.png)

# %%
#Matplotlib nedir? Kullanım alanları nelerdir?
#Matplotlib’in temel modülü: pyplot
#Grafiklerin oluşturulması ve gösterilmesi: plt.show()

# %%
#Matplotlib, Python dilinde grafikler ve görselleştirmeler oluşturmak için kullanılan popüler bir kütüphanedir. 
#Özellikle veri biliminde ve mühendislikte, verileri görselleştirerek anlamak için çok önemli bir araçtır.

# %%
#Matplotlib'in en çok kullanılan modülü pyplot adını taşır.
#Bu modül, grafik çizmek için basit ve etkili bir arabirim sağlar. 
# pyplot sayesinde:
#Çizgi grafikleri
#Çubuk grafikleri
#Pasta grafikleri
#Dağılım grafikleri gibi birçok türde grafik oluşturabilirsiniz.

# %%
# pip install Matplotlib

# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
plt.figure(figsize=(12,8))
plt.show()

# %% [markdown]
# Grafiklerin oluşturulması ve gösterilmesi

# %%
#fonksiyon =f(x)=2x
x=[0,1,2,3,4,5,6]
y=[0,2,4,6,8,10,12]

#plt.figure(figsize=(20,4))
plt.plot(x,y) #grafik oluşturmak için
plt.show()
