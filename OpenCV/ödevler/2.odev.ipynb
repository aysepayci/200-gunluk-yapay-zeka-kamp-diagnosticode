# %% [markdown]
# Nesne ve Yüz Tespiti

# %%
import cv2
import numpy as np

# %%
insanlar=cv2.imread('insanlar.png')

# %%
insanlar.shape
# Out:
# (1024, 1024, 3)

# %%
insanlar=cv2.resize(insanlar,(512,512))

# %%
cv2.imshow("insanlar",insanlar)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Konturlar ve Maskeleme:
#   Renk bazlı maskeleme yap.
#   Görseldeki konturları tespit et ve çiz.

# %%
hsv_insanlar = cv2.cvtColor(insanlar, cv2.COLOR_BGR2HSV)

# %%
cv2.imshow("hsv insanlar",hsv_insanlar)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#zombilere benzediler biraz :)

# %%
lower_red = np.array([0, 100, 100])   # Kırmızı için alt sınır
upper_red = np.array([10, 255, 255])  # Kırmızı için üst sınır
mask = cv2.inRange(hsv_insanlar, lower_red, upper_red)

# %%
result = cv2.bitwise_and(insanlar, insanlar, mask=mask)
cv2.imshow("Maske result", result)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
lower_blue = np.array([90, 50, 50])    # Mavi için alt sınır
upper_blue = np.array([130, 255, 255])  # Mavi için üst sınır
mask = cv2.inRange(hsv_insanlar, lower_blue, upper_blue)

# %%
result = cv2.bitwise_and(insanlar, insanlar, mask=mask)
cv2.imshow("maske resullt", result)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
lower_white = np.array([0, 0, 150])   # Beyaz için alt sınır (düşük doygunluk ve yüksek parlaklık)
upper_white = np.array([180, 50, 255])  # Beyaz için üst sınır (yüksek parlaklık)
mask = cv2.inRange(hsv_insanlar, lower_white, upper_white)

# %%
result = cv2.bitwise_and(insanlar, insanlar, mask=mask)
cv2.imshow("Masked Image (White)", result)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#bu bi tık gece trafikte kim görünür oldu :)

# %%
#Yüz Tanıma:
#   OpenCV’nin hazır haarcascade_frontalface_default.xml modelini kullanarak yüzleri algıla.
#   Algılanan yüzleri dikdörtgen içine al.

# %%
import cv2
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
# Resmi yükleyin
image = cv2.imread('insanlar.png')
cv2.imshow('Yuz Tanima', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image.shape
# Out:
# (1024, 1024, 3)

# %%
image=cv2.resize(image,(512,512))

# %%
cv2.imshow('Yuz Tanima', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imwrite('gray.png',gray)
cv2.imshow('Yuz Tanima', gray)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#hatayı bulamaadim ihşallah bulurum :(

# %%
# Yüzleri tespit edin
faces = faceCascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=3, minSize=(30, 30))

# Yüzleri çizin
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x+w, y+h), (255, 0, 0), 2)

# Sonucu gösterin
cv2.imshow('Yuz Tanima', image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[25], line 2
#       1 # Yüzleri tespit edin
# ----> 2 faces = faceCascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=3, minSize=(30, 30))
#       4 # Yüzleri çizin
#       5 for (x, y, w, h) in faces:
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\objdetect\src\cascadedetect.cpp:1689: error: (-215:Assertion failed) !empty() in function 'cv::CascadeClassifier::detectMultiScale'
