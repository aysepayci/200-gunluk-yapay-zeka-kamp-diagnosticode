# %% [markdown]
#     DataFrame

# %%
#DataFrame oluşturma.
#DataFrame özellikleri ( shape , columns , index ).
#DataFrame sütun ve satırlarına erişim.

#Ek Attribute:
"""
df.size (toplam eleman sayısı)
df.ndim (veri çerçevesinin boyutu)
df.dtypes (her sütunun veri tipleri)
df.axes (satır ve sütun etiketlerini döner)
"""
#Ek Metotlar:
"""
df.memory_usage() (hafıza kullanımı)
df.transpose() (DataFrame’i döndürür)
"""

# %% [markdown]
# DataFrame oluşturma

# %%
import numpy as np 
import pandas as pd

# %%
#pd.DataFrame() fonksiyonuyla basitçe df oluşturabiliriz.

# %%
my_data=np.random.randint(0,101, size=(5,4))
my_data
# Out:
# array([[67, 90, 16, 28],
#        [ 6, 92, 34, 12],
#        [66, 85, 75, 30],
#        [64, 61, 58, 56],
#        [ 7, 18, 45, 35]])

# %%
pd.DataFrame(my_data)
# Out:
#     0   1   2   3
# 0  67  90  16  28
# 1   6  92  34  12
# 2  66  85  75  30
# 3  64  61  58  56
# 4   7  18  45  35

# %%
my_idx=['TR','BR','USA','RU']
my_cols=['jan','feb','mar']
my_data=np.random.randint(0,101, size=(4,3))

# %%
df=pd.DataFrame(data=my_data,index=my_idx,columns=my_cols)
df
# Out:
#      jan  feb  mar
# TR     1    0   64
# BR    55   21   89
# USA   14   51   23
# RU    29   69   22

# %%
my_data
# Out:
# array([[ 1,  0, 64],
#        [55, 21, 89],
#        [14, 51, 23],
#        [29, 69, 22]])

# %%
df.info() # .info() metoduyla DF'in içinde bütün columnların temel bilgilerini görebiliriz.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, TR to RU
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   jan     4 non-null      int32
#  1   feb     4 non-null      int32
#  2   mar     4 non-null      int32
# dtypes: int32(3)
# memory usage: 80.0+ bytes

# %%
df.index=['ali','mehmet','burak','aslı']

# %%
df.columns=['1. not','2. not','3. not']

# %%
df
# Out:
#         1. not  2. not  3. not
# ali          1       0      64
# mehmet      55      21      89
# burak       14      51      23
# aslı        29      69      22

# %%
df=pd.read_csv('tips.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %% [markdown]
# DataFrame özellikleri

# %%
df.head() # baştan boş bırakırsam 5 tane alır
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df.tail() #son kısmını
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID
# 239    Michael Avila  5296068606052842    Sat2657
# 240   Monica Sanders  3506806155565404    Sat1766
# 241       Keith Wong  6011891618747196    Sat3880
# 242     Dennis Dixon     4375220550950      Sat17
# 243  Michelle Hardin  3511451626698139    Thur672

# %%
df.sample(5) #boş bırakırsam bir tane verir. rasgele yerlerden getirir.
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 198       13.00  2.00  Female    Yes  Thur   Lunch     2              6.50
# 14        14.83  3.02  Female     No   Sun  Dinner     2              7.42
# 195        7.56  1.44    Male     No  Thur   Lunch     2              3.78
# 196       10.34  2.00    Male    Yes  Thur   Lunch     2              5.17
# 85        34.83  5.17  Female     No  Thur   Lunch     4              8.71
#
#          Payer Name         CC Number Payment ID
# 198  Katherine Bond     4926725945192    Thur437
# 14    Vanessa Jones    30016702287574    Sun3848
# 195   Michael White  4865390263095532    Thur697
# 196     Eric Martin    30442491190342   Thur9862
# 85      Shawna Cook  6011787464177340   Thur7972

# %%
df.shape
# Out:
# (244, 11)

# %%
df.shape[1]
# Out:
# 11

# %%
df.columns #colums'ları liste halinde alıyoruz
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
# ...

# %%
df.describe() #Numeric columnların istatiksel özetini verir
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %% [markdown]
# Column(sütun) işlemleri

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df['price_per_person'] #seri
# Out:
# 0       8.49
# 1       3.45
# 2       7.00
# 3      11.84
# 4       6.15
#        ...
# 239     9.68
# 240    13.59
# 241    11.34
# 242     8.91
# 243     9.39
# Name: price_per_person, Length: 244, dtype: float64

# %%
df[['price_per_person']] #dataFrame
# Out:
#      price_per_person
# 0                8.49
# 1                3.45
# 2                7.00
# 3               11.84
# 4                6.15
# ..                ...
# 239              9.68
# 240             13.59
# 241             11.34
# 242              8.91
# 243              9.39
#
# [244 rows x 1 columns]

# %%
df[['sex','tip']] #istediğim parça analizi
# Out:
#         sex   tip
# 0    Female  1.01
# 1      Male  1.66
# 2      Male  3.50
# 3      Male  3.31
# 4    Female  3.61
# ..      ...   ...
# 239    Male  5.92
# 240  Female  2.00
# 241    Male  2.00
# 242    Male  1.75
# 243  Female  3.00
#
# [244 rows x 2 columns]

# %%
#Amaç: insanların bonkörlük düzeyini hesaplayın. 
#Not: Bonkorlük düzeyi "verilen bahsis/ödenen toplam ücret *100" şeklinde hesaplanır.

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
3.50/21.01*100
# Out:
# 16.658733936220845

# %%
df['bonkörlük_yüzdesi']=df['tip']/df['total_bill']*100

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  bonkörlük_yüzdesi
# 0  Christy Cunningham  3560325168603410    Sun2959           5.944673
# 1      Douglas Tucker  4478071379779230    Sun4608          16.054159
# 2      Travis Walters  6011812112971322    Sun4458          16.658734
# 3    Nathaniel Harris  4676137647685994    Sun5260          13.978041
# 4        Tonya Carter  4832732618637221    Sun2251          14.680765

# %%
df.drop('Payment ID',axis=1,inplace=True) #inplace drop işlemi kalıcı hale getirir. 
# .drop() düşürme işlem axis=1 colums belirtme

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number  bonkörlük_yüzdesi
# 0  Christy Cunningham  3560325168603410           5.944673
# 1      Douglas Tucker  4478071379779230          16.054159
# 2      Travis Walters  6011812112971322          16.658734
# 3    Nathaniel Harris  4676137647685994          13.978041
# 4        Tonya Carter  4832732618637221          14.680765

# %%
df.drop(['bonkörlük_yüzdesi','Payer Name'],axis=1)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#             CC Number
# 0    3560325168603410
# ...

# %% [markdown]
# Row(Satır) işlemleri

# %%
df['tip'] #sütun çekmek bu kadar basitti
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64
