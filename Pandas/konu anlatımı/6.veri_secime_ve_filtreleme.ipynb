# %% [markdown]
#     veri seçme ve filtreleme

# %%
#Eksik verileri bulma.
#Eksik verileri doldurma veya kaldırma.

#Ek Metotlar:
"""
df.interpolate() (eksik veriyi tahmin ederek doldurma)
"""

# %% [markdown]
# missing values (eksik veriler)

# %%
#makine öğrenmesi algoritamalarının pek çoğu missing valuelarla çalışmaz. bu yüzden bunları biz handle etmeliyiz. 
#missing value kavramı 'eksik veri anlamına gelir ve datamız içindeki değeri bilinmeyen verileri ifade eder.
#Missing valuelar farklı formatlarda olabilir.

# %%
import numpy as np
import pandas as pd

# %%
np.nan #en sık karşılaşacağımız eksik veri tipi
# Out:
# nan

# %%
pd.NA

# %%
pd.NaT
# Out:
# NaT

# %%
5==5
# Out:
# True

# %%
np.nan==np.nan # bir verinin nan olup olmadığını bu şekilde kontrol edemeyiz.
# Out:
# False

# %%
df=pd.read_csv('movie_scores.csv')
df.head()
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
df.isna()
# Out:
#    first_name  last_name    age    sex  pre_movie_score  post_movie_score
# 0       False      False  False  False            False             False
# 1        True       True   True   True             True              True
# 2       False      False  False  False             True              True
# 3       False      False  False  False            False             False
# 4       False      False  False  False            False             False

# %%
df.isna().sum()
# Out:
# first_name          1
# last_name           1
# age                 1
# sex                 1
# pre_movie_score     2
# post_movie_score    2
# dtype: int64

# %%
df.notna()
# Out:
#    first_name  last_name    age    sex  pre_movie_score  post_movie_score
# 0        True       True   True   True             True              True
# 1       False      False  False  False            False             False
# 2        True       True   True   True            False             False
# 3        True       True   True   True             True              True
# 4        True       True   True   True             True              True

# %%
df.head()
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
#amaç : pre_movie_score sütunu nan olmayan satırları getirmek

# %%
df[df['pre_movie_score'].notna()]
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
#amaç :post_movie_score'u nan olan satırarı getir.

# %%
df[df['pre_movie_score'].isna()]
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN

# %%
#post_movie_score'u nan olan. age sütunu nan olmayanlrı getir.

# %%
df.head()
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
df[(df['pre_movie_score'].isna())&(df['age'].notna())]
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 2       Hugh   Jackman  51.0   m              NaN               NaN

# %% [markdown]
# missing valuelarla yapılamayabilecek 3 şey var.

# %%
# 1) dokunmadan bırakabiliriz. 
# 2) drop edebiliriz (satır veya sütun bazlı)
# 3) mantıklı bir şekilde doldurabiliriz.

# %%
df
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
# 2.yol:

# %%
df.dropna()
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
df.dropna(how='all')
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 2       Hugh   Jackman  51.0   m              NaN               NaN
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
df.dropna(thresh=1) #1 tane bile nan olmayan veri varsa o satırı tut
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 2       Hugh   Jackman  51.0   m              NaN               NaN
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
df.dropna(thresh=5) #1 tane bile nan olmayan veri varsa o satırı tut
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
df.head()
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
df.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
df.dropna(axis=1,thresh=4)
# Out:
#   first_name last_name   age  sex
# 0        Tom     Hanks  63.0    m
# 1        NaN       NaN   NaN  NaN
# 2       Hugh   Jackman  51.0    m
# 3      Oprah   Winfrey  66.0    f
# 4       Emma     Stone  31.0    f

# %%
# 3. yol: fill the data (datayı doldur)

# %%
df.head()
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
df.dropna(how='all',inplace=True)

# %%
df.head()
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 2       Hugh   Jackman  51.0   m              NaN               NaN
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
df['pre_movie_score'].fillna(9.5)
# Out:
# 0    8.0
# 2    9.5
# 3    6.0
# 4    7.0
# Name: pre_movie_score, dtype: float64

# %%
df['pre_movie_score'].fillna(df['post_movie_score'].mean())
# Out:
# 0    8.0
# 2    9.0
# 3    6.0
# 4    7.0
# Name: pre_movie_score, dtype: float64

# %% [markdown]
# kopya verilerden kurtulma

# %%
simple_df=pd.DataFrame(data=[[1,2,2,2],[1,2,3,4],[1,2,2,2],[1,2,2,2]], index=['a','b','c','d'], columns=['col1','col2','col3','col4'])
simple_df
# Out:
#    col1  col2  col3  col4
# a     1     2     2     2
# b     1     2     3     4
# c     1     2     2     2
# d     1     2     2     2

# %%
simple_df.duplicated() #dataFrame'de kopya bulmak için kullanılır.
# Out:
# a    False
# b    False
# c     True
# d     True
# dtype: bool

# %%
simple_df.drop_duplicates()
# Out:
#    col1  col2  col3  col4
# a     1     2     2     2
# b     1     2     3     4

# %%
df=pd.read_csv('tips.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...
