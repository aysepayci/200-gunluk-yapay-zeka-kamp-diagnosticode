# %% [markdown]
#     Seaborn

# %%
#Seaborn nedir? Neden kullanılır?
#Seaborn ile Matplotlib arasındaki farklar
#Kurulum: pip install seaborn
#Temel modül: sns

# %%
#Seaborn, Python'da istatistiksel grafikler oluşturmak için bir kütüphanedir. Matplotlib'in üzerine kuruludur ve pandas veri yapılarıyla yakından bütünleşir.

# %%
#Seaborn verilerinizi keşfetmenize ve anlamanıza yardımcı olur. 
#Çizim işlevleri, tüm veri kümelerini içeren veri çerçeveleri ve diziler üzerinde çalışır.
#ve bilgilendirici çizimler üretmek için dahili olarak gerekli anlamsal eşlemeyi ve istatistiksel toplamayı gerçekleştirir. 
#Veri kümesi odaklı, bildirimsel API'si, çizimlerinizin farklı öğelerinin nasıl çizileceğine dair ayrıntılardan ziyade ne anlama geldiğine odaklanmanızı sağlar.

# %% [markdown]
# Matplotlib ve Seaborn arasındaki farklar

# %% [markdown]
# ![image.png](attachment:image.png)
# (chatgbt'den alınmıştır)

# %% [markdown]
# Seaborn kurulum ve kütüphaneyi çağırma

# %%
# pip install seaborn kütüphane yüklemek

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
plt.rcParams["figure.figsize"]=(6,8)

# %%
# minik örnek
#Bu grafik, seaborn işlevine tek bir çağrı kullanarak ipuçları veri kümesindeki beş değişken arasındaki ilişkiyi gösterir relplot().

# %%
sns.relplot(
    data=tips,
    x="total_bill", y="tip", col="time",
    hue="smoker", style="smoker", size="size",
)

# %%
#Matplotlib'i doğrudan kullanırken olduğu gibi, grafik öğelerinin özniteliklerini renk değerleri veya işaretleyici kodları açısından belirtmek gerekli değildi.
#Bu bildirimsel yaklaşım, matplotlib'i nasıl kontrol edeceğiniz konusundaki ayrıntılar yerine, yanıtlamak istediğiniz sorulara odaklanmanızı sağlar

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import seaborn as sns
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']
