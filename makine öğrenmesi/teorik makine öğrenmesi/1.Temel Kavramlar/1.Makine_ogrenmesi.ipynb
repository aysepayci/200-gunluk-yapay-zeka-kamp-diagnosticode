# %%
# kaynak olarak BTK akademiden Kaan Caan Yılmaz hocamızdan Makine öğrenmesi programı kullanılmıştır. 
#https://www.btkakademi.gov.tr/portal/course/makine-ogrenmesi-30123
# biraz teorik uygulama kısmı da olucak

# %% [markdown]
# makine öğrenmesi nedir

# %%
# Bilgisayar sistemlerinin veri kullanarak 
#     örütüleri tanıması
#     tahmin yapması
#     kararlar vermesi
# için algoritmalar ve istatiksel modeller kullanılan bir yapay zeka alanıdır.

# %% [markdown]
# makineler nasıl öğrenir

# %%
#yapay zeka algoritmaları, büyük miktarda veriye dayalı olarak desenleri tanımlar,kararlar alır ve sonuçları tahmin ederler.
#insanların öğrenme sürecine benzer şekilde, yapay zeka modelleri de hatalarından öğrenir ve deneyimleriyle daha iyi hale gelir.

# %% [markdown]
# Makine öğrenme kavramı nedir

# %%
#makine öğrenmesi,
#   bilgisayar sistemlerinin verilerden öğrenerek,
#   deneyimlerden yararlanarak,
#   algoritmalar kullanarak
# belirli görevleri gerçekleştirmesini sağlayan yapay zeka alanının bir alt dalıdır.

# %% [markdown]
# Makine öğrenmesi ve Geleneksel programlama

# %%
#programlama yaşlaşımı
#kural tabanlı bilgi
#Esneklik ve Genelleme
#Değişkenlik ve Adaptasyon

# %% [markdown]
# ![![image.png](attachment:image.png)](attachment:image.png)
