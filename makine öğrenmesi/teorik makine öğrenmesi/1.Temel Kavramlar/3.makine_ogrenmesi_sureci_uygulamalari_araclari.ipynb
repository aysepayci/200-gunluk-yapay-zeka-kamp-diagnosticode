# %% [markdown]
# makine öğrenmesi süreci

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#verilerin toplanması, düzenlenmesi ve bölünmesi 
#makine öğrenmesi modellerinin seçilmesi
#modelin Train edilmesi
#sonuçların değerlendirilmesi
#Hiperparametre Ayarlanması
#Modelin hizmete sunulması

#new input data=test

# %% [markdown]
# makine öğrenmesi uygulamaları

# %%
#Tıp ve Sağlık
#Finans
#Perakende ve Pazarlama - ör/ çevrimiçi alışveriş kişileşmis öneri
#Ulaşım ve Lojistik 
#Güvenlik ve Siber Güvenlik
#Sınır Güvenliği
#Robotik
#Enerji planlama ve Verimlilik

# %% [markdown]
# makine öğrenmesi araçları

# %%
#TensorFlow - Deep Learning
#PyTorch - Deep Learning
#Keras - Deep Learning
#NumPy - matamatiksel işlem matrix işlemleri
#Scikit-Learn - makine öğrenmesi için her şey var algoritma.. 
#Pandas - veri bilimi ile ilgili
#Matplotlib- temel görselleştirme
#Theano - Deep Learning
