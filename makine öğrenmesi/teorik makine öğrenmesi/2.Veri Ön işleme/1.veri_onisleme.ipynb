# %% [markdown]
# makine öğrenmesi için veri ön işleme

# %%
#veri nedir?
#veri ön işleme
#veri temizleme
#   kayıp veri problemi
#   tutarsız veri düzeltme
#   yinelenen verilerin silinmesi
#   gereksiz sütunların silinmesi
#veri kodlaması

# %% [markdown]
# veri

# %%
#veri, bilgi taşıyan ve anlam ifade eden öğelerin toplamıdır.
#Genellikle sayılar, metin, görseller veya diğer formatlardaki bilgileri içerir

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#nomiral kategorik ve sıralanamaz
#ordinal kategorik ve sıralanabilir
#interval sayısal ve aralık verileri mutlak sıfır yok
#ratio  sayısal ve oranlar yapılabilir.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# veri ön işleme

# %%
#veri setini hazırlma sürecidir. 
#veri ön işleme aşamaları genellikle şunlarrı içerir
#   veri temizleme
#   veri standardizasyonu
#   öznitelik seçimi
#   veri dönüşümü
#   aykırı değerlerin işlenmesi

# %% [markdown]
# veri temizleme

# %%
#veri temizleme, veri setindeki hatalı, eksik veya tutarsız verilerin tanımlama, düzeltme veya çıkarma işlemidir. 
#Bu işlem, verinin doğruluğunu artırarak modelleme süreçlerinin güveniliğini sağlar.

# %% [markdown]
# veri temizleme neden gerekli

# %%
#veri temizleme işlemi genellikle şu nedenlerle gereklidir. 
#   doğrululuk
#   tutarlılık
#   eksik veri problemi
#   aykırı değerler

# %% [markdown]
# veri temizleme yöntemleri

# %%
#kayıp veri problemi
#tutarsız veri düzeltme
#yinelenen verilerin silinmesi
#gereksiz sütunların silinmesi

# %% [markdown]
# kayıp veri problemi

# %%
#kayıp veri problemi, bir veri setinde eksik veya bozuk verilerin bulunması durumudur.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#satırı silebilirim ya da diğer verilere göre veri yazabilirim

# %% [markdown]
# tutarsız veri düzeltme

# %%
#tutarsız veri düzeltme, veri setindeki tutarsızlıkların tespit etme ve düzeltme

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#1 ve 3 deki kişiler aynı ise yaş ve medeni durauma göre birini çıkartma ya da farklı kişiler ise ekxtra bir id sütun ekleyip farkı gösterilebilir

# %% [markdown]
# yinelenen verilerin silinmesi

# %%
#veri setindeki tekrarlayan veya yinelenen verilerin tespit edilmesi ve bunların temizlenmesi işlemidir.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 1 ve 6 numaralı ıd ler tekrarladığı için birini çıkartırız
#2 num fiyata -3 yazılmış ya 3 ya da silincek satır
# 3 stok adedi -20 düzeltirir

# %% [markdown]
# Gereksiz Sütunların Silinmesi

# %%
#veri setinde analiz veya modelleme işlemleri için gerekli olmayan sütunların çıkarılması veya kaldırılması işlemidir.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# yıl_int ve yıl_str aynı olduğu için biri silinir

# %% [markdown]
# veri kodlaması

# %%
#veri kodlaması, kategorik (nominal veya ordinal) verileri sayısal değerlere dönüştürme işlemidir. 
#bu dönuşum, makine öğrenimi algoritmaları gibi birçok analiz yöntemi için gereklidir, çünkü bu algoritmalar genellikle sayısal verilerle çalışır. 
#veri kodlamasının iki ana türü vardır. 
#   nominal kodlama
#   ordinal kodlama

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# nominalde herhangi bir sıralama bulunmaz 
# ordinalde sıralama yapıyoruz
