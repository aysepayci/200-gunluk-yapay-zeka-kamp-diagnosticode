# %% [markdown]
# veri tipleri ve dönüşümleri

# %%
#Ayrık ve sürekli veri ayırma
#veri bölme
#dengesiz veri işleme

# %% [markdown]
# Ayrık ve sürekli veri ayırma

# %%
#ayrık (discrete) ve sürekli (continuous) veri, istatistik ve veri bilimi alanlarında temel olarak iki farklı veri tipini ifade eder.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# veri bölme

# %%
#veri bölme , bir veri setini eğitim, doğrulama ve test kümeleri olarak üçe veya fazla parçaya ayırmak anlamına gelir. 
#bu bölme işlemi, makine öğrenimi modellerinin eğitilmesi, doğrulanması ve değerlendirilmesi için kullanılır. 
#genellikle, veri setinin büyük bir kısmı modelin eğitimi için kullanılırken, geri kalan kısmı modelin doğrulanması için test edilmesi için kullanılır.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#ML 1000 80-10-10 ve DL 10000 verim varsa 90-5-5 bölerim

# %% [markdown]
# veri bölme

# %%
#veri bölme makine öğrenimi açısından önemi
#   model prformansının doğru değerlendirilmesi
#   aşırı uydurma önlenmesi
#   parametre ayarının ve model seçiminin yapılması

# %% [markdown]
# dengesiz veri işleme

# %%
#makine öğrenmesi dengesiz veri, farkllı sınıfların ait örneklerin sayısal olarak büyük farklılıklar gösterdiği durumları ortaya çıkarır. 
#örneğin, bir sınıfın örnek sayısı diğerlerine göre çok daha fazlaysa, bu dengesiz veri problemi olarak kabul edilir. 
#Dengesiz veri, modelin eğitimini ve performansını olumsuz yönde etkileyebilir çünkü nadir sınıfları öğrenilmesi zorlaşabilir ve modelin tanımlanması daha düşük olabilir.

# %% [markdown]
# dengesiz veri işleme yöntemleri

# %%
#oversampling (aşırı örnekleme)
#undersampling (yetersiz örnekleme)
#sentetik örnekleme (synthetic sampling)

# %% [markdown]
# ![image.png](attachment:image.png)
