# %% [markdown]
# kalkülüs

# %%
#türev
#integral

# %% [markdown]
# Türev

# %%
#türev bir foksiyonun belirli bir noktasındaki anlık değişim oranını ifade eder
#özellikle gradyan inişi gibi optimizasyon teknikleri, bir fonksiyonuun türevini kullanarak en uygun parametre değerlerini bulmaya çalışır. 
#nodelin kayıp fonksiyonunun (loss function) türevi, parametre güncellemelerinde bir rehber olarak kullanılır.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# integral

# %%
#integral, bir fonksiyonun belirli bir aralıktaki alanını ifade eder. 
#integral, bir fonsiyonun toplamını almak için kullanılır ve belirli bir aralıkta sonsuz küçük parçaların toplamını hesaplamak için integral işareti kullanılır.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
