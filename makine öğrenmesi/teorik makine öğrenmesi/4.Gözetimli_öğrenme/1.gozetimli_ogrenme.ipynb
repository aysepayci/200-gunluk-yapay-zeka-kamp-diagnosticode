# %% [markdown]
# Gözetimli öğrenme

# %%
#Gözetimli öğrenme nedir?
#Gözetimli öğrenme algoritmaları

# %%
#gözetimli öğrenme eğitim verilerinden girdi ve çıktı arasındaki ilişkiyi öğrenmeyi amaçlayan bir makine örenmesi yaklaşımıdır. 
#bu tür öğrenme genellikle "etiketllenmiş veri" ile gerçekleşir, yani her girdiye karşılık genel bir çıktı etiketi bulunur. 
#gözetimli öğrenmenin ana adımları şunlardır:
#   veri toplama ve hazırlığı
#   model seçimi ve eğitimi
#   model değerlendirmesi
#   model yatrlanması ve hiperparametre optimazasyonu
#gözetimli öğrenme, sınıflandırma ve regresyon gibi çeşitli problemleri çözmek için kullanılabilir. 
#örnek uygulamalar arasında hastalık teşhisi, müşteri tercihleri tahmin etme, pazar segmentasyonu ve hisse senedi fiyatlarını tahmin etme bulunmaktadır.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Gözetimli öğrenme algoritmaları

# %%
#sınıflandırma
#   k-En yakın komşu
#   karar ağaçları
#   rasgele orman
#   logistic regresyon
#   destek vektör makinesi
#   Naive Bayes
#Regresyon
#   Lineer Regresyon
#   Çoklu Lineer Regresyon
#   Polinom Regresyon
