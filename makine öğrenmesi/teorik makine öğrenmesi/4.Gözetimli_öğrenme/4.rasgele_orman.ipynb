# %% [markdown]
# Rasgele Orman

# %%
# Rasgele orman
# Rasgele orman türleri
# Rasgele orman Hiperparametreleri
# Uygulama Alanları
# Zayıf ve Güçlü Yönleri

# %%
# Rasgele ormanlar , birden çok karar ağacının bir araya gelerek bir prman oluşturduğu bir toplluk öğrenme yöntemidir
# ensemble learning=topluluk öğrenmesi
# Her karar ağacı, farklı bir alt örneklem (bootstrap sample) ve/veya alt özellikler (random subset of features) kullanarak eğitilir.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Rasgele orman türleri

# %%
#Sınıflandırma için Rasgele Ormanlar
#Regresyon için Rasgele Ormanlar

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Ragele Orman Hiperparametreleri

# %%
#Ağaç Sayısı (n_estimators)
#Özelliklerin Sayısı (max_features)
#Ağaç Derinliği (max_depth)
#Örnekleme Oranı (bootstrap)

# %% [markdown]
# Uygulama Alanları

# %%
#Sınıflandırma
#Regresyon

# %% [markdown]
# ![image.png](attachment:image.png)
