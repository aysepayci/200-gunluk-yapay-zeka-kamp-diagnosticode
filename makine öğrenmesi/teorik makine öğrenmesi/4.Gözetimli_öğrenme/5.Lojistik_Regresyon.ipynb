# %% [markdown]
# Lojistik Regresyon

# %%
#Lojistik Regresyon
#Lojistik Regresyon Tahmini
#Lojistik Regresyon Eğitimi
#Durum Çalışması
#Lojistik Regresyon Hiperparametreleri
#Uygulama Alanları
#Zayıf ve Güçlü Yönleri

# %%
#Lojistic regresyon, istatik ve makine öğrenmesi alanlarında sınıflandırma problemlerini çözmek için kullanılan bir yöntemdir. 
#Genellikle bağımlı değişkenin kategorik olduğu durumlarda kullanılır. 
#Örneğin, bir müşterinin bir ürünü satın alıp almama olasılığını tahmin etmek gibi durumlarda kullanılabilir.

# %% [markdown]
# Lojistik Regresyon Tahmini

# %%
#İleri yayılım (Forward Propagation) input=x verilmesi x'lerin weight=w ile çarpılması w bias ile toplanması sonra bias'ın sigmoit fonksiyonuna sokulması
#baştan sona ilerledik

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#amaç classifiction 3D px[0-255] 12287=feature x=input

# %%
#LR öğrenme= w,b parametrelerinin belirlenmesi

# %% [markdown]
# Lojistik Regresyon Eğitimi

# %%
#Ağırlık ve Biaslerin başlatılması
#ileri yayılım (Forward Propagation)
#Loss Fonsiyonunun hesaplanması L(y^,y)
#Geri yayılım (Backward Propagation) türev hesapla
#Ağırlıkların güncellenmesi gradient descent

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#y^=predicted value

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#gradient desrent
#alfa=LR hyperparametre 10^-3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Logistik Regresyon Hiperparametreleri

# %%
#penalty (Cezalandırma)
#C (Cezalandırma katsayısı)
#Solver (Çözücü)
#Max iterations (maximym iterasyonlar)
#Class weight (sınıf ağırlığı)

# %% [markdown]
# Uygulama Alanları

# %%
#Tıp ve sağlık
#finans
#insan kaynakları

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#LR+NLK=DL
