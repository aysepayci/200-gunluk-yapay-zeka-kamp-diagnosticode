# %% [markdown]
# Destek vektör makinesi

# %%
# destek vektör makinesi
# durum çalışması
# destek vektör makinesi hiperparametreleri
# uygulama alanlanları
# zayıf ve güçlü yönleri

# %%
# Destek vektör makineleri (SVM), sınıflandırma ve regresyon problemlerini çözmek için kullnılan güçlüü bir makine öğrenimi algoritmasıdır.
# SVM, veri kümesini sınıflar arasında en iyi şekilde ayıran bir hiperdüzlem bulmaya çalışır.
# SVM, özellikle doğrusal olmayan veri kümeleri için etkilidir, çünkü kernel yöntemi kullanarak veriyi daha yüksek boyutlu uzalara dönüştürerek doğrusal olarak ayrılabilir bir yapı elde edebilir.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Durum çalışması

# %% [markdown]
# ![alt text](<WhatsApp Image 2025-03-11 at 17.33.30.jpeg>)

# %% [markdown]
# Destek vektör makineleri hiperparametreleri

# %%
#C
#Kernel tipi

# %% [markdown]
# Uygulama alanları

# %%
#tıp
#finans
#görüntü işleme
#Biyoinformatik
#metin ve dil işleme

# %% [markdown]
# ![image.png](attachment:image.png)
