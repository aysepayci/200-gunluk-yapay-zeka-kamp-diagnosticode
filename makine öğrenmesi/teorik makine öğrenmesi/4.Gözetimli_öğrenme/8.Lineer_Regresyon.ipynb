# %% [markdown]
# Lineer Regresyon

# %%
# Lineer Regresyon
# Lineer Regresyon türleri
# durum çalışması
# uygulama alanları
# zayıf ve güçlü yönleri

# %%
# Lineer Regresyon iki ya da daha fazla değişken arasındaki ilişkiyi modellemek için kullanılan istatistiksel bir yöntemdir.
# Özellikle, bağımsız değişken (genellikle x olarak adlandırılır) bağımlı değişkene (genellikle y olarak adlandırılır) olan etkisini tahmin etmek için kullanılır.

# %%
#örnek
#ev fiyatı=a0+0.5a1+Bahçedurumua2
#y=a0+x1a1+x2a2 Lineer

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#deta1=bias=intercept
#deta2=slope

# %% [markdown]
# Lineer Regresyon türleri

# %%
#basit lineer regresyon -bir tane bağımsız değişken- y=ax+b
#çoklu lineer regresyon -birden fazla bağımsız değişken- y=ax1+bx2+cx3+b
#polinom regresyon -lineer olmayanlar için- y=b+ax1+cx2^2+dx3^3
#Ridge ve Lasso regresyonu -aşırı uydurmayı azaltmak için kullanılır-
#katsayıların karelerinin toplamı=0 model karmaşıklığını azaltır
#katsayılarının mutlak tolamak=0

# %% [markdown]
# Durum çalışması

# %% [markdown]
# ![alt text](<WhatsApp Image 2025-03-14 at 15.04.53.jpeg>)

# %% [markdown]
# Uygulama alanları

# %%
#ekonomi ve finans
#pazarlama
#sağlık bilimleri

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Çoklu Lineer Regresyon

# %%
#çoklu lineer regresyon
#durum çalışması
#uygulama alanları

# %%
#çoklu lineer regresyon, birden fazla bağımsız değişkenein kullanıldığı bir regresyon türüdür.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#örnek olarak, bir evin satış fiyatını tahmin etmek için çoklu lineer regresyon kullanalım
#bağımlı değişkenimiz ev fiyatı olsun
#bağımsız değişkenimiz ise aşağıdaki gibi faktörler olsun
    #ev alanı
    #oda sayısı
    #banyo sayısı
    #mahalle güvenlik puanı

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Durum çalışması

# %% [markdown]
# ![alt text](<WhatsApp Image 2025-03-14 at 17.28.22.jpeg>)

# %% [markdown]
# Uygulama alanları

# %%
# pazarlama
# finans
# sağlık bilimleri

# %% [markdown]
# Polinom Regresyon

# %%
# polinom regresyon
# durum çalışması
# polinom regresyon hiperparametreleri
# uygulama alanları

# %%
#Lineer regresyonun genişletilmiş bir versiyonudur ve doğrusal olmayan ilişkileri modellemek için kullanılır.
#polinom regresyonunda bağımsız değişkenlerin doğrusal birleşimleri yerine polinom terimleri kullanılır.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Durum çalışması

# %% [markdown]
# ![alt text](<WhatsApp Image 2025-03-14 at 17.27.58.jpeg>)

# %% [markdown]
# polinom regresyon hiperparametreleri

# %%
#polinom regresyonunun hiperparametreleri, genellikle polinomun derecesini belirlemek için seçilir.
#polinom regresyonunda hiperparametre seçimini etkileyen bazı faktörler şunlardır:
#   modelin performansı
#   aşırı uyum ve aşırı basitlik
#   bilgi kaybı

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Uygulama alanları

# %%
#fizik ve mühendislik
#finans ve ekonomi
#iklim bilimi
#tıp ve sağlık bilimleri
#eğitim ve öğrenme analizi

# %% [markdown]
# ![image.png](attachment:image.png)
