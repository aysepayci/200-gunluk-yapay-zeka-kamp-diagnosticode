# %% [markdown]
# K-Ortalama Kümeleme

# %%
# K-ortalamalar (K-Means) kümeleme, bir gözetimsiz öğrenme algoritmasıdır ve veri setindeki benzer örnekleri belirli sayıda kümelere gruplamak için kullanılır.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Küme merkezi başlatma
# veri noktalarını kümelere atama
# küme merkezlerini yeniden hesapla
# yeniden atama ve güncelleme

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![alt text](<WhatsApp Image 2025-03-14 at 18.08.44.jpeg>)
