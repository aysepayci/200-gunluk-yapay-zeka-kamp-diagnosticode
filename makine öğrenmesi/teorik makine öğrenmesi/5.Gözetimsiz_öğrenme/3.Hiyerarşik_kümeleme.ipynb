# %% [markdown]
# Hiyerarşik kümeleme

# %%
# Hiyerarşik Kümeleme, veri setindeki örnekleri bir hiyerarşik yapı içinde gruplamak için kllanılan bir gözetimsiz öğrenme yöntemidir.
# Bu yöntemde, her veri noktası bir küme olarak başlar ve ardından benzerlikleri veya uzaklıkları temel alarak bu kümeler birleştiri veya bölünür
# Bu işlem, bir ağaç benzeri bir hiyerarşi oluşturur. Hiyerarşik Kümeleme, iki ana türde gerçekleşebilir:
#     Aglomeratif (Birleştirici) Hiyerarşik kümeleme
#     Bölücü Hiyerarşik Kümeleme

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Aglomeratif (Birleştirici) Hiyerarşi Kümeleme Örneği

# %% [markdown]
# ![alt text](<WhatsApp Image 2025-03-16 at 00.45.42.jpeg>)

# %% [markdown]
# Bölücü Hiyerarşik Kümeleme Örneği

# %% [markdown]
# ![alt text](<WhatsApp Image 2025-03-16 at 00.46.07.jpeg>)
