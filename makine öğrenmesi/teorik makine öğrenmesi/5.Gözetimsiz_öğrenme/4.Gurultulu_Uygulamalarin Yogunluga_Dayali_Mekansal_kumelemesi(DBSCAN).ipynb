# %% [markdown]
# Gürültülü Uygulamaların Yoğunluğa Dayaalı Mekansal Kümelemesi (DBSCAN)

# %%
#Gürültülü Uygulamaların Yoğunluğa Dayaalı Mekansal Kümelemesi (Density-Based spatial Clustering of Applications with Noise-DBSCAN), gözetimsiz bir kümeleme algoritmasıdır ve özellikle belirsiz şekilli küme yapılarına sahip veri settlerini işlemek için kullanılır
#DBSCAN, veri noktalarının yoğunluğuna ve birbirine olan mesafelerine dayanarak kümeleme yapar
#Bu nedenle, DBSCAN belirli bir küme sayısı veya şekli gerektirmez ve gürültülü veri setlerinde iyi çalışabilir.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![alt text](<WhatsApp Image 2025-03-16 at 00.46.30.jpeg>)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# DBSCAN Örneği

# %% [markdown]
# ![alt text](<WhatsApp Image 2025-03-16 at 00.46.50.jpeg>)
