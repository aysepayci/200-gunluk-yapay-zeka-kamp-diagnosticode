# %% [markdown]
# Pekiştirmeli Öğrenme

# %%
#pekiştirmeli öğrenme
#pekiştirmeli öğrenme türleri
#pekiştirmeli öğrenme terimleri
#pekiştirmeli öğrenme nasıl çalışır?
#pekiştirmeli öğrenme algoritmaları
#pekiştirmeli öğrenme uygulama alanları

# %%
#pekiştirmeli öğrenme, bir yapay zeka (AI) modelinin, bir ortamda etkileşime geçerek belirli bir görevi gerçekleştirmeyi öğrenmesini sağlayan bbir öğrenme türüdür.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Pekiştirmeli öğrenme türleri

# %%
#model tabanlı pekiştirmeli öğrenme
#model tabanlı olmayan pekiştirmeli öğrenme
#Değer tabanlı pakiştirmeli öğrenme
#politika tabanlı pekiştirmeli öğrenme

# %% [markdown]
# Pekiştirmeli Öğrenme Terimleri

# %%
#Agent -ajan- çevreyi algılayabilen keşfedebilen deneyebilen
#Environment
#Action -ajanın ortam içinde hamleleri eylemleri
#State -durumdur her eylem için enviroment daki durumdur
#Reward -ödül negetif de olabilir geri bildirimler
#Policy -ajanın bir sonraki eylem için uyguladığı strajedi
#Value beklenen uzun vadeli dönüşümü
#Q-value mevcut bir eyleme ek parametre

# %% [markdown]
# Pekiştirmeli öğrenem nasıl çalışır?

# %%
#At şuan zamanı karşılıyo t0
#St+1 bir sonraki anda hangi stade de olduğu

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# pekiştirmeli öğrenme algoritmaları

# %%
#Q-Learning Q-kalite
#Deep Q-Learning -sinir ağları- karmaşık ve büyük ölçek

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# pekiştirmeli öğrenme uygulama alanları

# %%
# Robotik 
#Kontrol
#Oyun Oynama
#işletme
#üretim
#finans sektörü
