# %% [markdown]
# Temel Bileşen Analizi (PCA)

# %%
# Boyut intirgeme nedir?
# Temel Birleşen analizi (PCA)
# Durum çalışması

# %% [markdown]
# Boyut indirgeme nedir?

# %%
# Makine öğrenmesi boyut indirgeme, veri setindeki değişken sayısını azaltarak modelin performansını arttırmayı veya hesaplama süresini azaltmayı amaçlayan bir tekniktir.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Öznitelik seçimi (Feature Selection) -en önemli featureları seçme
#Öznitelik Çıkarma (Feature Extraction) -çıkarma değil türetmedir

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Temel Birleşen Analizi (PCA)

# %%
# Temel bileşen analizi (Principal component analysis -PCA), çok boyutlu veri setlerindeki değişkenliği azaltmak için kullanılan bir boyut indirgeme tekniğidir. 
# PCA, veri setindeki orjinal değişkenler arasındaki korelasyonu dikkate alarak, bu değişkenlerin birbiriyle olan ilişkisini açıklamak için yeni bir değişken seti oluşturulur.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# veri Normalizasyonu
# kovaryans matrisinin hesaplanması -iki değişken arasındaki değişimin ölçümü-
# Koveryans matrisinin özdeğer ve özvektörlerinin hesaplanması
# Özdeğerlerin sıralanması
# Temel bileşen seçimi
# yeni veri setinin oluşturulması

# %% [markdown]
# Durum çalışması

# %% [markdown]
# ![alt text](<WhatsApp Image 2025-03-18 at 16.16.04.jpeg>)

# %% [markdown]
# ![alt text](<WhatsApp Image 2025-03-18 at 16.17.20.jpeg>)
