# %% [markdown]
# Sınıflandırma için değerlendirme metrikleri

# %%
# değerlendirme metriği nedir?
# sınıflandırma için değerlendirme metrikleri
#     doğruluk
#     kesinlik
#     duyarlılık
#     F-1 score
#     ROC scorekarmaşıklık matrisi (Confusion matrix)

# %% [markdown]
# değerlendirme metriği nedir?

# %%
#machine learning modellerinin performansını değerlendirmek için çeşitli metrikler kullanılır
#hem sınıflandırma (classification) hem regresyon (regression) problemleri için farklı değerlendirme metrikleri vardır

# %% [markdown]
# Doğruluk (Accuracy)

# %%
#Doğru tahminlerin oranını ifade eder

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Kesinlik (Precision)

# %%
#positif olarak tahmin edilen örneklerin ne kadarının gerçekten pozitif olduğunu gösterir

# %% [markdown]
# Duyarlılık (Recall)

# %%
#gerçek pozitiflerin ne kadarının doğru bir şekilde tanındığını gösterir

# %% [markdown]
# F-1S core

# %%
#precision ve recall'in harmonik ortalaması -F-1Score 1 e ne kadar yakınca o kadar iyi

# %% [markdown]
# ROC Score

# %%
#Receiver Operating Characteristic (ROC) eğrisi altındaki alanı ifade eder.
#Sınıflandırma modellinin performansını değerlendirmek için kullanılır

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Karmaşıklık Matrisi (Confusion Matrix)

# %%
#gerçek ve tahmin edilen sınıfları karşılaştıran bir tablodur

# %% [markdown]
# ![image.png](attachment:image.png)
